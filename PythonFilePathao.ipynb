# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('pathaoUpdated.csv')

# %%
df
# Out:
#       star                                  date  \
# 0        1                     November 17, 2018
# 1        1                        March 21, 2017
# 2        1         March 22, 2017 March 23, 2017
# 3        1         March 21, 2017 March 23, 2017
# 4        1         March 21, 2017 March 23, 2017
# 5        1         March 22, 2017 March 23, 2017
# 6        1            March 22, 2017 May 3, 2017
# 7        1         March 21, 2017 March 23, 2017
# 8        1         March 22, 2017 March 23, 2017
# 9        1      November 8, 2018 August 17, 2017
# 10       1                        March 21, 2017
# 11       1     November 6, 2018 November 7, 2018
# 12       1         March 21, 2017 March 23, 2017
# 13       1            April 13, 2017 May 3, 2017
# 14       1        November 8, 2018 June 22, 2017
# 15       1     September 29, 2018 April 13, 2018
# 16       1   September 29, 2018 November 8, 2018
# 17       1            March 18, 2017 May 3, 2017
# ...

# %%
new = df['star'].str[23:24]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-39af089e8eb0> in <module>()
# ----> 1 new = df['star'].str[23:24]
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\Anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df.loc[[0:10],['star']]
# Out:
#   File "<ipython-input-21-62a523647dfa>", line 1
#     df.loc[[0:10],['star']]
#              ^
# SyntaxError: invalid syntax

# %%
df['star']=new

# %%
df['star']
# Out:
# 0       2
# 1       1
# 2       5
# 3       2
# 4       1
# 5       1
# 6       1
# 7       1
# 8       1
# 9       1
# 10      5
# 11      1
# 12      1
# 13      3
# 14      1
# 15      5
# 16      5
# 17      1
# 18      5
# 19      1
# 20      5
# 21      4
# 22      5
# 23      3
# 24      5
# 25      5
# 26      5
# 27      5
# 28      4
# 29      2
#        ..
# 8313    5
# 8314    5
# 8315    5
# 8316    5
# 8317    5
# 8318    5
# 8319    5
# 8320    5
# 8321    5
# 8322    5
# 8323    5
# 8324    5
# 8325    3
# 8326    5
# 8327    5
# 8328    5
# 8329    5
# 8330    5
# 8331    5
# 8332    5
# 8333    5
# 8334    3
# 8335    5
# 8336    5
# 8337    5
# 8338    5
# 8339    5
# 8340    4
# 8341    3
# 8342    5
# Name: star, Length: 8343, dtype: object

# %%
df.sort_values('star',inplace=True)

# %%
df.to_csv('PathaoUpdated.csv',index=False)

# %%
fb.to_csv('PathaoUpdatedFacebook.csv',index=False)

# %%
df[df['Review Text'].apply(lambda x: len(x)>1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-33153fed245b> in <module>()
# ----> 1 df[df['Review Text'].apply(lambda x: len(x)>1)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-12-33153fed245b> in <lambda>(x)
# ----> 1 df[df['Review Text'].apply(lambda x: len(x)>1)]
#
# TypeError: object of type 'float' has no len()

# %%
df['Review Text'] = df['Review Text'].astype('str')

# %%
mask = (df['Review Text'].str.len() > 40) & ((df['star'] <5))

# %%
df.loc[mask].sort
# Out:
#       star                                  date  \
# 0        1                     November 17, 2018
# 7        1         March 21, 2017 March 23, 2017
# 8        1         March 22, 2017 March 23, 2017
# 9        1      November 8, 2018 August 17, 2017
# 10       1                        March 21, 2017
# 11       1     November 6, 2018 November 7, 2018
# 12       1         March 21, 2017 March 23, 2017
# 14       1        November 8, 2018 June 22, 2017
# 15       1     September 29, 2018 April 13, 2018
# 17       1            March 18, 2017 May 3, 2017
# 20       1  September 20, 2018 November 10, 2018
# 21       1                     February 28, 2017
# 22       1                     November 10, 2018
# 23       1                     November 10, 2018
# 24       1                        March 13, 2017
# 25       1  September 25, 2018 November 11, 2018
# 26       1                     November 10, 2018
# 27       1                     November 10, 2018
# ...

# %%
df['star'] = df['star'].astype('int')

# %%
m2 = (df['star'] ==1)

# %%
m2
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9        True
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 8313    False
# 8314    False
# 8315    False
# 8316    False
# 8317    False
# 8318    False
# 8319    False
# 8320    False
# 8321    False
# 8322    False
# 8323    False
# 8324    False
# 8325    False
# 8326    False
# 8327    False
# 8328    False
# 8329    False
# 8330    False
# 8331    False
# 8332    False
# 8333    False
# 8334    False
# 8335    False
# 8336    False
# 8337    False
# 8338    False
# 8339    False
# 8340    False
# 8341    False
# 8342    False
# ...

# %%
df.loc[(df['star'] <4)].sort_values('Review Like',ascending=False)
# Out:
#       star                                 date  \
# 739      1     February 20, 2018 March 21, 2018
# 1719     1                     November 9, 2018
# 3341     3                       April 29, 2018
# 1746     1                    November 10, 2018
# 1479     1    October 24, 2018 November 4, 2018
# 2696     2  November 17, 2017 December 14, 2017
# 1475     1    October 24, 2018 November 4, 2018
# 3322     3    October 15, 2017 October 16, 2017
# 3044     3  February 19, 2018 February 27, 2018
# 1692     1                    November 14, 2018
# 2948     3    January 21, 2018 January 24, 2018
# 2905     3      March 23, 2017 January 11, 2018
# 1716     1                     November 9, 2018
# 1747     1                     November 9, 2018
# 2922     3    November 9, 2018 January 11, 2018
# 3127     3  September 29, 2018 November 8, 2018
# 1314     1     November 11, 2018 March 21, 2018
# 733      1    February 6, 2018 February 6, 2018
# ...

# %%
mask = (df['Review Text'].str.len() > 40) & ((df['star'] <4))

# %%
df.loc[mask].sort_values('Review Like',ascending=False).sort_values('star',ascending=True)
# Out:
#       star                                 date  \
# 739      1     February 20, 2018 March 21, 2018
# 119      1                         May 10, 2018
# 94       1                    November 14, 2018
# 135      1                     November 9, 2018
# 137      1                    November 14, 2018
# 138      1                    November 14, 2018
# 139      1                    November 10, 2018
# 140      1     October 6, 2018 November 7, 2018
# 142      1                     November 9, 2018
# 144      1                       April 29, 2018
# 145      1                    November 10, 2018
# 146      1    August 19, 2018 November 12, 2018
# 97       1                        June 10, 2018
# 103      1    November 3, 2018 November 1, 2018
# 105      1                    November 10, 2018
# 106      1                     November 9, 2018
# 108      1         March 6, 2018 March 23, 2018
# 109      1                        June 15, 2018
# ...

# %%
word_count = df['Review Text'].str.split(expand=True).stack().value_counts()

# %%
word_count.to_csv('word_count.csv')

# %%
word_count.to_excel('word_count.xlsx',sheet_name='NewSheet')

# %%
word_count.columns = ['Name','Count']

# %% [raw]
# word_count

# %%
word_count
# Out:
# the                     2023
# to                      1803
# is                      1516
# and                     1473
# app                     1402
# I                       1236
# a                       1100
# for                      898
# good                     879
# of                       879
# it                       873
# in                       760
# this                     733
# my                       637
# Good                     625
# not                      605
# are                      536
# service                  534
# very                     488
# but                      445
# you                      439
# be                       422
# This                     384
# should                   378
# your                     371
# they                     362
# personal                 358
# from                     354
# have                     352
# ride                     351
#                         ...
# reject                     1
# ...

# %%
fb = pd.read_excel("pathao_facebook_scrap.xlsx")

# %%
nunu = pd.read_excel("pathao_facebook_scrap.xlsx")

# %%
nunu
# Out:
#                                                    post comment count  \
# 0     Looking for two person who will manage to driv...     1 Comment
# 1     ...And most importantly, You don't have to reg...    2 Comments
# 2     #ফ্রি_৫০_টাকা_ iPay Bangladesh (ডিজিটাল ব্যাংক...           NaN
# 3     Personal + Uber/Pathao\nড্রাইভার প্রয়োজন !!!\...   18 Comments
# 4     ...and share his motorcycle to help you reach ...   52 Comments
# 5     So, #Pathao has got full access to over 2ml mo...           NaN
# 6     When your younger brother is your personal Pat...     1 Comment
# 7                                                   NaN           NaN
# 8     Mazda Axela 2005  Price: ৳7,50,000  Dhaka, Ban...     1 Comment
# 9     Personal + Uber\nড্রাইভার প্রয়োজন  জানুয়ারী ম...    4 Comments
# 10    ...your decision that do you use the pathao se...           NaN
# 11    Handi dhanmondi. Call -01977742634.01841242634...           NaN
# ...

# %%
fb.dropna()
# Out:
# Empty DataFrame
# Columns: [post, comment count, reaction count, User name, Post date, post privacy]
# Index: []

# %%
fbNa = fb.dropna()

# %%
fbWithoutNa = fb.dropna(subset=['post','comment count'])

# %%
fb.drop('post privacy',1, inplace=True)

# %%
fb.dropna(subset=['post','comment count'],inplace=True)

# %%
fb['comment count'] = fb['comment count'].str[0:-8]

# %%
aa = map(lambda x: x.replace("June","6"), fb['Post date'])

# %%
aa[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-04cafb779ff7> in <module>()
# ----> 1 aa[1]
#
# TypeError: 'map' object is not subscriptable

# %%
yearMonth = {"January":"1","February":"2","March":"3","April":"4","May":"5","June":"6","July":"7","August":"8","September":"9","October":"10","November":"11","December":"12"}

# %%
yearMonth
# Out:
# {'April': '4',
#  'August': '8',
#  'December': '12',
#  'February': '2',
#  'January': '1',
#  'July': '7',
#  'June': '6',
#  'March': '3',
#  'May': '5',
#  'November': '11',
#  'October': '10',
#  'September': '9'}

# %%
aa = map(lambda x,y: fb['Post date'].str.replace(x,y) for x,y in yearMonth)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-7d57c0c9372f> in <module>()
# ----> 1 aa = map(lambda x,y: fb['Post date'].str.replace(x,y) for x,y in yearMonth)
#
# TypeError: map() must have at least two arguments.

# %%
aa
# Out:
# <generator object <genexpr> at 0x0000016BE476DE60>

# %%
fb['Post date'].str.replace(x,y) for x,y in yearMonth
# Out:
#   File "<ipython-input-36-743af44c4081>", line 1
#     fb['Post date'].str.replace(x,y) for x,y in yearMonth
#                                        ^
# SyntaxError: invalid syntax

# %%
for x in yearMonth.keys():
    fb['Post date'] = fb['Post date'].str.replace(x,yearMonth[x])

# %%
fb['Time'] = fb['Post date'].str[-8:]

# %%
fb['Post date'] = fb['Post date'].str[:-11]

# %%
fb['reaction count']=fb['reaction count'].str.replace("K","000")

# %%
fb.dtypes
# Out:
# post              object
# comment count     object
# reaction count    object
# User name         object
# Post date         object
# Time              object
# dtype: object

# %%
for x,y in fb['reaction count'].iteritems():
    if "." in str(y):
        fb['reaction count'][x] = y[:-1]
        #print(fb['reaction count'][x]+" "+str(x))
        #print(y)
# Out:
# C:\Users\Sadman\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fb['reaction count'] = fb['reaction count'].str.replace(".","")

# %%
fb
# Out:
#                                                    post comment count  \
# 0     Looking for two person who will manage to driv...             1
# 1     ...And most importantly, You don't have to reg...            2
# 3     Personal + Uber/Pathao\nড্রাইভার প্রয়োজন !!!\...           18
# 4     ...and share his motorcycle to help you reach ...           52
# 6     When your younger brother is your personal Pat...             1
# 8     Mazda Axela 2005  Price: ৳7,50,000  Dhaka, Ban...             1
# 9     Personal + Uber\nড্রাইভার প্রয়োজন  জানুয়ারী ম...            4
# 12    Personal + Uber/Pathao\nড্রাইভার প্রয়োজন !!!\...            2
# 13    ...and share his motorcycle to help you reach ...           51
# 14    ...asa....So jodi kew akta poramordso ditan......            3
# 15    Dear Pathao & Pathao Users Of Bangladesh, I wo...           43
# 16    AssalamuAlaiqum, I need a job, I have a job in...             1
# ...

# %%
fb.columns = ['Review','Comment_Count','Reaction','Name','Date','Time']

# %%
fb

# %%
for x in yearMonth.keys():
    df['date'] = df['date'].str.replace(x,yearMonth[x])

# %%
fb.columns
# Out:
# Index(['Review', 'Comment_Count', 'Reaction', 'Name', 'Date', 'Time'], dtype='object')

# %%
df.columns = ['Star','Date','Name','Reaction','Review']

# %%
df
# Out:
#       Star                     Date                                  Name  \
# 0        1              11 17, 2018                           Siddiq Khan
# 1647     1               11 9, 2018                       BlueRage Arifin
# 1648     1    11 9, 2018 11 8, 2018     Md. Abdullah Al-Alamin Pathao Inc
# 1649     1               11 9, 2018                          Isteak Hamid
# 1650     1              11 10, 2018                       Rayhan Abdullah
# 1651     1              11 13, 2018                           imran lemon
# 1652     1              11 12, 2018                         A Google user
# 1653     1               11 9, 2018                    S. M. NAHIDUZZAMAN
# 1654     1  11 17, 2018 11 19, 2018              A Google user Pathao Inc
# 1655     1              11 16, 2018                             anik saha
# 1656     1              11 10, 2018                     Fatema Tuj Jahura
# 1657     1              11 10, 2018                            Fahim Himu
# ...

# %%
combined = pd.concat([df,fb])
# Out:
# C:\Users\Sadman\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
combined
# Out:
#      Comment_Count                     Date  \
# 0              NaN              11 17, 2018
# 1647           NaN               11 9, 2018
# 1648           NaN    11 9, 2018 11 8, 2018
# 1649           NaN               11 9, 2018
# 1650           NaN              11 10, 2018
# 1651           NaN              11 13, 2018
# 1652           NaN              11 12, 2018
# 1653           NaN               11 9, 2018
# 1654           NaN  11 17, 2018 11 19, 2018
# 1655           NaN              11 16, 2018
# 1656           NaN              11 10, 2018
# 1657           NaN              11 10, 2018
# 1658           NaN              11 10, 2018
# 1659           NaN              11 10, 2018
# 1660           NaN              11 12, 2018
# 1661           NaN   11 10, 2018 3 14, 2018
# 1646           NaN              11 15, 2018
# 1662           NaN  11 16, 2018 11 17, 2018
# 1645           NaN              11 12, 2018
# 1643           NaN              11 12, 2018
# ...

# %%
mask = (cm['Review'].str.len() > 10)

# %%
combined['Reaction'][358] = 151
# Out:
# C:\Users\Sadman\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
combined["Reaction"] = pd.to_numeric(combined["Reaction"])

# %%
cm = combined

# %%
cm.loc[mask]
# Out:
#      Comment_Count                     Date  \
# 0              NaN              11 17, 2018
# 1647           NaN               11 9, 2018
# 1648           NaN    11 9, 2018 11 8, 2018
# 1649           NaN               11 9, 2018
# 1650           NaN              11 10, 2018
# 1651           NaN              11 13, 2018
# 1653           NaN               11 9, 2018
# 1654           NaN  11 17, 2018 11 19, 2018
# 1655           NaN              11 16, 2018
# 1657           NaN              11 10, 2018
# 1659           NaN              11 10, 2018
# 1660           NaN              11 12, 2018
# 1661           NaN   11 10, 2018 3 14, 2018
# 1646           NaN              11 15, 2018
# 1662           NaN  11 16, 2018 11 17, 2018
# 1645           NaN              11 12, 2018
# 1643           NaN              11 12, 2018
# 1628           NaN               11 9, 2018
# 1629           NaN              11 12, 2018
# 1630           NaN              11 10, 2018
# ...

# %%
cm = cm.drop_duplicates()

# %%
cm
# Out:
#      Comment_Count                     Date  \
# 0              NaN              11 17, 2018
# 1647           NaN               11 9, 2018
# 1648           NaN    11 9, 2018 11 8, 2018
# 1649           NaN               11 9, 2018
# 1650           NaN              11 10, 2018
# 1651           NaN              11 13, 2018
# 1652           NaN              11 12, 2018
# 1653           NaN               11 9, 2018
# 1654           NaN  11 17, 2018 11 19, 2018
# 1655           NaN              11 16, 2018
# 1656           NaN              11 10, 2018
# 1657           NaN              11 10, 2018
# 1658           NaN              11 10, 2018
# 1659           NaN              11 10, 2018
# 1660           NaN              11 12, 2018
# 1661           NaN   11 10, 2018 3 14, 2018
# 1646           NaN              11 15, 2018
# 1662           NaN  11 16, 2018 11 17, 2018
# 1645           NaN              11 12, 2018
# 1643           NaN              11 12, 2018
# ...

# %%
cm
# Out:
#      Comment_Count                     Date  \
# 0              NaN              11 17, 2018
# 1647           NaN               11 9, 2018
# 1648           NaN    11 9, 2018 11 8, 2018
# 1649           NaN               11 9, 2018
# 1650           NaN              11 10, 2018
# 1651           NaN              11 13, 2018
# 1652           NaN              11 12, 2018
# 1653           NaN               11 9, 2018
# 1654           NaN  11 17, 2018 11 19, 2018
# 1655           NaN              11 16, 2018
# 1656           NaN              11 10, 2018
# 1657           NaN              11 10, 2018
# 1658           NaN              11 10, 2018
# 1659           NaN              11 10, 2018
# 1660           NaN              11 12, 2018
# 1661           NaN   11 10, 2018 3 14, 2018
# 1646           NaN              11 15, 2018
# 1662           NaN  11 16, 2018 11 17, 2018
# 1645           NaN              11 12, 2018
# 1643           NaN              11 12, 2018
# ...
